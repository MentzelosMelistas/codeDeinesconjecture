# %%
#Lemma 2.2 Part (ii): computation of A^2+AB+B^2, A'^2+A'B'+B'^2, and (A^2+AB+B^2)-(A'^2+A'B'+B'^2)

R.<t>=QQ[]
v=364*t+1
u=364*t+5
A=v*(16*v-u)
B=16*(16*u^2-v^2)
Aprime=16*u^2-v^2
Bprime=16*u*(16*v-u)
print ('A^2+AB+B^2 is', A^2+A*B+B^2)
print()
print ('A\'^2+A\'B\'+B\'^2 is', Aprime^2+Aprime*Bprime+Bprime^2)
print()
print ('(A^2+AB+B^2)-(A\'^2+A\'B\'+B\'^2) is', A^2+A*B+B^2-Aprime^2-Aprime*Bprime-Bprime^2)
# Out:
# A^2+AB+B^2 is 1078327546732800*t^4 + 60689835198720*t^3 + 1274643054048*t^2 + 11819759952*t + 40825801
#
# A'^2+A'B'+B'^2 is 1078327546732800*t^4 + 34906855576320*t^3 + 354967118688*t^2 + 1177870512*t + 1284721
#
# (A^2+AB+B^2)-(A'^2+A'B'+B'^2) is 25782979622400*t^3 + 919675935360*t^2 + 10641889440*t + 39541080

# %%
#Lemma 2.2 Parts (vii) and (viii): compuation of AB(A+B)

R.<t>=QQ[]
v=364*t+1
u=364*t+5
A=v*(16*v-u)
B=16*(16*u^2-v^2)
print ('AB(A+B) is', A*B*(A+B))
# Out:
# AB(A+B) is 2135261074938421248000*t^6 + 130710551904763084800*t^5 + 3118842418505748480*t^4 + 36219784702087168*t^3 + 207018434558208*t^2 + 516389304704*t + 449082480

# %%
#Lemma 2.2 Parts (vii) and (viii): compuation of p(1)

t=1
p1=2135261074938421248000*t^6 + 130710551904763084800*t^5 + 3118842418505748480*t^4 + 36219784702087168*t^3 + 207018434558208*t^2 + 516389304704*t + 449082480
print (p1)
# Out:
# 2269126896581665113840
